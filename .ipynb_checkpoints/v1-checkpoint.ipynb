# %%
import pandas as pd
import json

# content = pd.read_json('data/volume_control/set_by_volume.json')
# content.head()

content = json.load(open('data/volume_control/combined_volume.json'))
content
# Out:
# {'reduce the volume adjuster': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'bring down the sound output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume adjuster level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume setting quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'soften the audio': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume control quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the sound output level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'bring down the volume': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'bring down the volume adjuster': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume button': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'turn the volume down': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume level lower': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the sound level level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the sound intensity level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'turn down the volume slider': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the volume output level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the sound lower': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the volume knob': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume button level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'turn down the volume control': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'quiet down the sound level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume setting': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'bring down the audio': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'quiet down the volume level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'diminish the volume': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the audio level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'bring down the volume output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume slider lower': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume regulator quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the audio level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'bring down the volume knob': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'turn down the audio': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the volume': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'quiet down the volume slider': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the sound intensity': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'tone down the sound output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'quiet down the volume knob': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume slider quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'quiet down the volume button': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume slider': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'soften the volume knob': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make it less loud': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the sound level lower': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'turn down the sound output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume adjuster': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'soften the volume adjuster': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the volume regulator': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the sound intensity': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'quiet down the volume output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume knob quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'soften the volume output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the audio lower': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the audio': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume slider level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the sound level quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'soften the sound output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume knob': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the volume adjuster': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the sound output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the volume regulator': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the sound': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume output quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'soften the sound intensity': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make it less deafening': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the volume button': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the volume slider': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume regulator': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make it less loudness': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'soften the volume button': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume output level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume control': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the volume setting': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the volume button': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'quiet down the volume setting': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the sound output level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make it less ear piercing': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume setting lower': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'bring down the volume button': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the volume output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'turn down the volume output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'turn down the volume regulator': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume button lower': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'quiet down the volume regulator': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'bring down the volume control': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume level quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the volume control': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'bring down the volume level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'bring down the volume slider': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the sound': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the sound intensity': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'soften the sound level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume control lower': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the volume control': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'turn down the sound intensity': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'quiet down the audio': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the sound output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the volume knob': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume regulator level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the volume slider': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the audio level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the volume level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'quiet down the volume adjuster': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the volume output level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume knob lower': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the sound output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the volume': {'intent': 'volume.decrease',
#   'entities': {'volume': '0'}},
#  'turn down the volume': {'intent': 'volume.decrease',
#   'entities': {'volume': '0'}},
#  'decrease the sound level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make it quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the sound level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume regulator lower': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make it less blaring': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the sound output level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume adjuster lower': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume button quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'tone down the sound intensity': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'bring down the volume setting': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'soften the volume regulator': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'turn down the sound level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the audio': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the volume level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume adjuster quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the sound intensity level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume setting level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'bring down the sound intensity': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the volume setting': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'tone down the audio': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'quiet down the volume control': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'quiet down the sound output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'soften the volume': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume control level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'soften the sound': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make it less noisy': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the sound output quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'quiet down the sound intensity': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'lower the audio': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'decrease the volume knob level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the volume output lower': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the volume output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make it less boisterous': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the sound output lower': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the sound intensity lower': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'tone down the volume': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the sound intensity level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the audio quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'quiet down the volume': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'bring down the volume regulator': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'bring down the sound level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'tone down the volume output': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'reduce the sound level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'silence the volume': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the sound intensity quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'make the sound quieter': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'turn down the volume level': {'intent': 'volume.decrease',
#   'entities': {'volume': 'current_volume - volume_decrement'}},
#  'turn the volume knob up': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the volume higher': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'raise the volume knob': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the voice more distinct': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'louden the voice output': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make it more understandable': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'raise the audio level higher': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'amplify the voice': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the voice clearer': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'louden the audio output even more': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'amplify the audio': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'up the volume intensity': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the volume as high as it can go': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the volume stronger': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'increase the volume strength': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'turn the volume up': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the voice more audible': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'amplify the audio output even more': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the voice clearer still': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'boost the audio intensity': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the volume as high as it can possibly go possible': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'increase the volume power': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the sound clearer': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'boost the volume output': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'louden the audio level': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'increase the volume intensity': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the volume as high as possible': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'amplify the voice output': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'turn the volume up to the max': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'raise the volume control': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'increase the volume level': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'louden the volume': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the volume as high as it will go possible': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make it more pronounced': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'turn the volume up all the way': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'raise the audio setting': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make it more clear': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'raise the decibel level': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'increase the sound power': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the volume as high as it will go': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'increase the audio intensity': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'amplify the audio output': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'increase the sound level': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'amplify the volume': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the voice louder': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'boost the audio volume': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the voice even more distinct': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the sound louder': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'raise the volume output higher': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'increase the volume output': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'raise the audio level': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make it more distinct': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'up the volume': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'raise the volume level higher': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'turn the volume up even more': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the volume as high as it can possibly go': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'increase the loudness': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the volume louder still': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'increase the sound intensity': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'boost the voice volume': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'raise the volume setting': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'turn the volume higher': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'boost the volume': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'up the voice volume': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'increase the audio power': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make it more audible': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'turn the volume knob to the right': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make it louder': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the volume as loud': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'up the volume level': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'raise the volume': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the sound stronger': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'up the volume strength': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'louden the audio output': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'increase the audio strength': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'up the audio volume': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'elevate the volume': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'amplify the audio level': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make audio louder': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'boost the voice intensity': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'raise the audio output': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'turn up the volume': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'turn the volume up more': {'intent': 'volume.increase',
#   'entities': {'volume': 'current_volume + volume_increment'}},
#  'make the voice as clear as it can get': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the voice as clear as possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the audio setting to the maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume up to the loudest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'louden the audio output to the loudest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume up to the maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the audio strength to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the volume to the maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'set the volume to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'louden the audio level to the loudest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the sound as loud as it can go': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'amplify the voice output to the maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume up to maximum possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the volume as loud as it can be raised to the': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the volume to the highest level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make it as audible as it can be raised': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the volume to its maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the volume as loud as it can be': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make it as audible as it can be': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'push the volume button to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume up to the maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume control to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the voice as distinct as it can be raised to': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the volume as loud as it can get': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'boost the audio intensity to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume up to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'set the volume to the highest setting possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the audio power to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make it as distinct as possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'louden the audio level to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'louden the audio level to the maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the volume as loud as it can be turned up to the': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'amplify the audio level to the maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the audio level to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the audio setting to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the sound strength to the loudest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume knob all the way to the right': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'adjust the volume to full blast possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make it as audible as it can get': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the volume power to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make it as audible as possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume all the way to the right': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the volume to the highest level possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the voice as clear as it can be turned up': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume output to the maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'amplify the voice output to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'louden the audio level to the maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'up the volume strength to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the voice as clear as it can be': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'boost the audio intensity to the maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the volume to its maximum setting possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the volume as loud as it can be raised': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn up the volume to its highest point': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'set the volume to maximum level possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the sound as loud as it can be raised to': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the audio power to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the voice as distinct as it can be turned up to': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume control to the maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make it as distinct as it can be': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the audio strength to the loudest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the audio level to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'louden the audio output to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the volume power to the loudest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the audio strength to the maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'up the volume intensity to the maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'adjust the volume to its maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume output to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume up to full': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume to its maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'louden the audio level to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'amplify the voice output to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the sound as loud as possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the voice as distinct as it can be': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the voice as distinct as it can be raised': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume to its highest setting possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the voice as clear as it can be raised': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make it as distinct as it can get': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume up to the highest point possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'boost the voice intensity to the loudest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the sound strength to the maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the volume to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the volume as loud as it will possibly go': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'adjust the volume to its maximum setting possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'set the volume to the highest level possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the sound strength to the maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'boost the voice intensity to the maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the sound as loud as it can be': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the audio strength to the maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume to the highest level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'up the volume strength to the maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume to the maximum level possible.': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'up the volume strength to the maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'push the volume button to the maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make it as distinct as it can be raised': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'set the volume to maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'amplify the voice output to the maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'up the volume strength to the loudest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the audio power to the maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'set the volume to full blast': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'set the volume to the highest level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'push the volume button to the maximum setting possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume output to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the volume power to the maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'crank the volume to its highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'louden the audio output to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the sound as loud as it will go': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the sound as loud as it can be raised to the': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume to its maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume control to the maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'amplify the audio level to the loudest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume to the highest level possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'amplify the audio level to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the sound as loud as it can be turned up to the': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the audio strength to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make it as distinct as it can be turned up': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn up the volume to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume output to the loudest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the voice as distinct as it can get': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the sound as loud as it can be turned up to': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the sound as loud as it can be raised': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'set the volume to maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'up the volume intensity to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'up the volume strength to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn up the volume to its highest point possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume all the way up to the right possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume to full blast': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'adjust the volume to maximum level possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the volume as loud as it can possibly be possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the audio setting to the maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume up to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the volume as loud as it can possibly be': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the volume as loud as it will go': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume to its highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'adjust the volume to maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the volume power to the maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the sound strength to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume to its highest level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'up the volume intensity to the loudest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume up to full possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume to the maximum level possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make it as audible as it can be turned up': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'boost the voice intensity to the maximum level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make it as distinct as it can be turned up to': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the volume as loud as it can be possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume to the maximum setting possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the volume as loud as it can be turned up to': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the volume as loud as it can go': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'set the volume to maximum possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the sound as loud as it can be turned up': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume up to the highest level': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'turn the volume to its maximum setting possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'set the volume to 100%': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the volume power to the highest setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'increase the sound strength to maximum': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'louden the audio output to the maximum setting': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'raise the volume to the highest level possible': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make it as audible as it can go': {'intent': 'volume.value',
#   'entities': {'volume': 'volume_max'}},
#  'make the volume as loud as it can be turned up': {'intent': 'volume.value',
# ...
#  'increase the volume to 47': {'intent': 'volume.value',
#   'entities': {'volume': '47'}},
#  'turn up the volume to 4': {'intent': 'volume.value',
#   'entities': {'volume': '4'}},
#  'change the volume to 18 on the controller': {'intent': 'volume.value',
#   'entities': {'volume': '18'}},
#  'make the volume 17': {'intent': 'volume.value',
#   'entities': {'volume': '17'}},
#  'alter the volume to 42': {'intent': 'volume.value',
#   'entities': {'volume': '42'}},
#  'set the volume to 45 for the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '45'}},
#  'set the volume to 76 on the audio system': {'intent': 'volume.value',
#   'entities': {'volume': '76'}},
#  'amplify the volume to 25': {'intent': 'volume.value',
#   'entities': {'volume': '25'}},
#  'set the volume level to 71': {'intent': 'volume.value',
#   'entities': {'volume': '71'}},
#  'set the volume to 16 within the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '16'}},
#  'set the audio to 29': {'intent': 'volume.value',
#   'entities': {'volume': '29'}},
#  'set the volume to a level of 68': {'intent': 'volume.value',
#   'entities': {'volume': '68'}},
#  'set the volume to 10 from the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '10'}},
#  'set the volume to 17 from the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '17'}},
#  'set the volume to 88 at the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '88'}},
#  'raise the volume to 49': {'intent': 'volume.value',
#   'entities': {'volume': '49'}},
#  'set the volume to 30 on the device': {'intent': 'volume.value',
#   'entities': {'volume': '30'}},
#  'set the audio to 32': {'intent': 'volume.value',
#   'entities': {'volume': '32'}},
#  'increase the volume to 73': {'intent': 'volume.value',
#   'entities': {'volume': '73'}},
#  'down the volume to 24': {'intent': 'volume.value',
#   'entities': {'volume': '24'}},
#  'set the audio to 14': {'intent': 'volume.value',
#   'entities': {'volume': '14'}},
#  'set the volume to 46 on a scale of 0-100': {'intent': 'volume.value',
#   'entities': {'volume': '46'}},
#  'change the volume to 39 on a scale of 1-10': {'intent': 'volume.value',
#   'entities': {'volume': '39'}},
#  'set the volume control to 4': {'intent': 'volume.value',
#   'entities': {'volume': '4'}},
#  'set the volume to 12 in the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '12'}},
#  'change the volume to 97 on a scale of 1-10': {'intent': 'volume.value',
#   'entities': {'volume': '97'}},
#  'adjust the volume to a setting of 91': {'intent': 'volume.value',
#   'entities': {'volume': '91'}},
#  'set the volume to 2 in the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '2'}},
#  'set the volume to 44 within the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '44'}},
#  'set the volume to 22 percent': {'intent': 'volume.value',
#   'entities': {'volume': '22'}},
#  'set the volume to 88': {'intent': 'volume.value',
#   'entities': {'volume': '88'}},
#  'set the volume equal to 48': {'intent': 'volume.value',
#   'entities': {'volume': '48'}},
#  'decrease the volume to 26': {'intent': 'volume.value',
#   'entities': {'volume': '26'}},
#  'turn the volume knob to 17': {'intent': 'volume.value',
#   'entities': {'volume': '17'}},
#  'lower the volume to 79 on the slider': {'intent': 'volume.value',
#   'entities': {'volume': '79'}},
#  'turn the volume up to 67': {'intent': 'volume.value',
#   'entities': {'volume': '67'}},
#  'change the volume to 10 on a scale of 1-10': {'intent': 'volume.value',
#   'entities': {'volume': '10'}},
#  'set the volume to 85 on the dial': {'intent': 'volume.value',
#   'entities': {'volume': '85'}},
#  'set the volume to 38 in the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '38'}},
#  'turn the volume knob to 68': {'intent': 'volume.value',
#   'entities': {'volume': '68'}},
#  'set the volume to 57 percent': {'intent': 'volume.value',
#   'entities': {'volume': '57'}},
#  'adjust the volume to 6 on the knob': {'intent': 'volume.value',
#   'entities': {'volume': '6'}},
#  'set the volume to 71 on the audio device': {'intent': 'volume.value',
#   'entities': {'volume': '71'}},
#  'set the volume to 70 on the device': {'intent': 'volume.value',
#   'entities': {'volume': '70'}},
#  'set the volume to 75 percent': {'intent': 'volume.value',
#   'entities': {'volume': '75'}},
#  'adjust the volume to a setting of 41': {'intent': 'volume.value',
#   'entities': {'volume': '41'}},
#  'set the volume equal to 99': {'intent': 'volume.value',
#   'entities': {'volume': '99'}},
#  'set the volume to 42 decibels': {'intent': 'volume.value',
#   'entities': {'volume': '42'}},
#  'set the volume equal to 80': {'intent': 'volume.value',
#   'entities': {'volume': '80'}},
#  'down the volume to 47': {'intent': 'volume.value',
#   'entities': {'volume': '47'}},
#  'set the volume to 22 on the device': {'intent': 'volume.value',
#   'entities': {'volume': '22'}},
#  'set the sound to 52': {'intent': 'volume.value',
#   'entities': {'volume': '52'}},
#  'set the volume control to 38': {'intent': 'volume.value',
#   'entities': {'volume': '38'}},
#  'turn the volume down to 48': {'intent': 'volume.value',
#   'entities': {'volume': '48'}},
#  'adjust the volume to 18 on the knob': {'intent': 'volume.value',
#   'entities': {'volume': '18'}},
#  'set the volume to 72 with the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '72'}},
#  'minimize the volume to 74': {'intent': 'volume.value',
#   'entities': {'volume': '74'}},
#  'set the volume control to 49': {'intent': 'volume.value',
#   'entities': {'volume': '49'}},
#  'set the volume control to 65': {'intent': 'volume.value',
#   'entities': {'volume': '65'}},
#  'make the volume 39': {'intent': 'volume.value',
#   'entities': {'volume': '39'}},
#  'set the volume to 12 within the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '12'}},
#  'lower the volume to 8 on the slider': {'intent': 'volume.value',
#   'entities': {'volume': '8'}},
#  'set the volume to 39 with the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '39'}},
#  'raise the volume to 82': {'intent': 'volume.value',
#   'entities': {'volume': '82'}},
#  'set the volume to 52 using the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '52'}},
#  'set the volume to 56 via the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '56'}},
#  'set the volume to 45 on the audio device': {'intent': 'volume.value',
#   'entities': {'volume': '45'}},
#  'lower the volume to 11 on the slider': {'intent': 'volume.value',
#   'entities': {'volume': '11'}},
#  'lower the volume to 68 on the slider': {'intent': 'volume.value',
#   'entities': {'volume': '68'}},
#  'set the volume to 82 out of 10': {'intent': 'volume.value',
#   'entities': {'volume': '82'}},
#  'set the volume to 66 within the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '66'}},
#  'minimize the volume to 16': {'intent': 'volume.value',
#   'entities': {'volume': '16'}},
#  'set the volume to 35 via the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '35'}},
#  'set the volume to 39 for the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '39'}},
#  'adjust the sound level to 20': {'intent': 'volume.value',
#   'entities': {'volume': '20'}},
#  'set the volume to 82 percent': {'intent': 'volume.value',
#   'entities': {'volume': '82'}},
#  'minimize the volume to 55': {'intent': 'volume.value',
#   'entities': {'volume': '55'}},
#  'set the volume to 81 on a scale of 0-100': {'intent': 'volume.value',
#   'entities': {'volume': '81'}},
#  'make the volume 16': {'intent': 'volume.value',
#   'entities': {'volume': '16'}},
#  'turn the volume up to 35': {'intent': 'volume.value',
#   'entities': {'volume': '35'}},
#  'change the volume to 93 on the controller': {'intent': 'volume.value',
#   'entities': {'volume': '93'}},
#  'lower the volume to 95': {'intent': 'volume.value',
#   'entities': {'volume': '95'}},
#  'set the volume to 29 on the dial': {'intent': 'volume.value',
#   'entities': {'volume': '29'}},
#  'turn the volume up to 0': {'intent': 'volume.value',
#   'entities': {'volume': '0'}},
#  'turn the volume down to 56': {'intent': 'volume.value',
#   'entities': {'volume': '56'}},
#  'set the volume to 16 at the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '16'}},
#  'raise the volume to 10': {'intent': 'volume.value',
#   'entities': {'volume': '10'}},
#  'change the volume to 82 on a scale of 1-10': {'intent': 'volume.value',
#   'entities': {'volume': '82'}},
#  'turn the volume down to 52': {'intent': 'volume.value',
#   'entities': {'volume': '52'}},
#  'change the volume to 19 on a scale of 1-10': {'intent': 'volume.value',
#   'entities': {'volume': '19'}},
#  'set the volume to 49': {'intent': 'volume.value',
#   'entities': {'volume': '49'}},
#  'set the volume control to 72': {'intent': 'volume.value',
#   'entities': {'volume': '72'}},
#  'set the volume to 31 within the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '31'}},
#  'set the volume to 0 in the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '0'}},
#  'set the volume to 55 from the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '55'}},
#  'down the volume to 98': {'intent': 'volume.value',
#   'entities': {'volume': '98'}},
#  'diminish the volume to 4': {'intent': 'volume.value',
#   'entities': {'volume': '4'}},
#  'raise the volume to 28 on the slider': {'intent': 'volume.value',
#   'entities': {'volume': '28'}},
#  'set the volume to be 91': {'intent': 'volume.value',
#   'entities': {'volume': '91'}},
#  'adjust the sound level to 14': {'intent': 'volume.value',
#   'entities': {'volume': '14'}},
#  'set the volume to 44 for the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '44'}},
#  'set the volume to 87 using the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '87'}},
#  'set the volume to 56 on the audio system': {'intent': 'volume.value',
#   'entities': {'volume': '56'}},
#  'set the volume to 77 on a scale of 0-100': {'intent': 'volume.value',
#   'entities': {'volume': '77'}},
#  'adjust the volume to 88 on the scale': {'intent': 'volume.value',
#   'entities': {'volume': '88'}},
#  'change the volume to 100 on a scale of 1-10': {'intent': 'volume.value',
#   'entities': {'volume': '100'}},
#  'raise the volume to 51 on the slider': {'intent': 'volume.value',
#   'entities': {'volume': '51'}},
#  'set the volume to 91 with the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '91'}},
#  'set the sound to 83': {'intent': 'volume.value',
#   'entities': {'volume': '83'}},
#  'minimize the volume to 87': {'intent': 'volume.value',
#   'entities': {'volume': '87'}},
#  'change the volume to 95 on a scale of 1-10': {'intent': 'volume.value',
#   'entities': {'volume': '95'}},
#  'set the volume to 50 percent': {'intent': 'volume.value',
#   'entities': {'volume': '50'}},
#  'alter the volume to 89': {'intent': 'volume.value',
#   'entities': {'volume': '89'}},
#  'down the volume to 5': {'intent': 'volume.value',
#   'entities': {'volume': '5'}},
#  'lower the volume to 60 on the slider': {'intent': 'volume.value',
#   'entities': {'volume': '60'}},
#  'set the volume level to 12': {'intent': 'volume.value',
#   'entities': {'volume': '12'}},
#  'set the volume to 78 from the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '78'}},
#  'set the volume to 55 via the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '55'}},
#  'maximize the volume to 76': {'intent': 'volume.value',
#   'entities': {'volume': '76'}},
#  'set the volume to 24 on the audio system': {'intent': 'volume.value',
#   'entities': {'volume': '24'}},
#  'set the volume to 86 from the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '86'}},
#  'set the volume to 78 under the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '78'}},
#  'down the volume to 16': {'intent': 'volume.value',
#   'entities': {'volume': '16'}},
#  'adjust the volume to a setting of 53': {'intent': 'volume.value',
#   'entities': {'volume': '53'}},
#  'set the volume to 76 through the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '76'}},
#  'change the volume to 37 on the controller': {'intent': 'volume.value',
#   'entities': {'volume': '37'}},
#  'set the volume to be 99': {'intent': 'volume.value',
#   'entities': {'volume': '99'}},
#  'turn the volume up to 38': {'intent': 'volume.value',
#   'entities': {'volume': '38'}},
#  'set the volume to 41 from the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '41'}},
#  'set the volume control to 23': {'intent': 'volume.value',
#   'entities': {'volume': '23'}},
#  'lower the volume to 100': {'intent': 'volume.value',
#   'entities': {'volume': '100'}},
#  'decrease the volume to 40': {'intent': 'volume.value',
#   'entities': {'volume': '40'}},
#  'set the volume to 56 within the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '56'}},
#  'alter the volume to 19': {'intent': 'volume.value',
#   'entities': {'volume': '19'}},
#  'set the volume equal to 54': {'intent': 'volume.value',
#   'entities': {'volume': '54'}},
#  'set the volume control to 19': {'intent': 'volume.value',
#   'entities': {'volume': '19'}},
#  'set the volume to 0 on the dial': {'intent': 'volume.value',
#   'entities': {'volume': '0'}},
#  'set the volume to 78 out of 10': {'intent': 'volume.value',
#   'entities': {'volume': '78'}},
#  'lower the volume to 97 on the slider': {'intent': 'volume.value',
#   'entities': {'volume': '97'}},
#  'set the volume to 78 via the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '78'}},
#  'set the volume to 51 for the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '51'}},
#  'set the volume to 76 within the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '76'}},
#  'diminish the volume to 12': {'intent': 'volume.value',
#   'entities': {'volume': '12'}},
#  'set the volume control to 0': {'intent': 'volume.value',
#   'entities': {'volume': '0'}},
#  'set the volume level to 95': {'intent': 'volume.value',
#   'entities': {'volume': '95'}},
#  'set the volume to 25 via the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '25'}},
#  'turn up the volume to 0': {'intent': 'volume.value',
#   'entities': {'volume': '0'}},
#  'set the volume to be 35': {'intent': 'volume.value',
#   'entities': {'volume': '35'}},
#  'minimize the volume to 70': {'intent': 'volume.value',
#   'entities': {'volume': '70'}},
#  'change the sound level to 62': {'intent': 'volume.value',
#   'entities': {'volume': '62'}},
#  'set the volume to 21 under the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '21'}},
#  'change the volume to 94': {'intent': 'volume.value',
#   'entities': {'volume': '94'}},
#  'change the volume to 49 on the controller': {'intent': 'volume.value',
#   'entities': {'volume': '49'}},
#  'amplify the volume to 15': {'intent': 'volume.value',
#   'entities': {'volume': '15'}},
#  'adjust the volume to 82': {'intent': 'volume.value',
#   'entities': {'volume': '82'}},
#  'adjust the volume to 52 on the system': {'intent': 'volume.value',
#   'entities': {'volume': '52'}},
#  'set the volume to 95 within the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '95'}},
#  'set the volume to 32 in the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '32'}},
#  'set the volume equal to 38': {'intent': 'volume.value',
#   'entities': {'volume': '38'}},
#  'set the volume to 90 from the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '90'}},
#  'set the sound to 92': {'intent': 'volume.value',
#   'entities': {'volume': '92'}},
#  'set the volume to 30 within the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '30'}},
#  'set the volume level at 78': {'intent': 'volume.value',
#   'entities': {'volume': '78'}},
#  'make the volume 3': {'intent': 'volume.value', 'entities': {'volume': '3'}},
#  'lower the volume to 13 on the slider': {'intent': 'volume.value',
#   'entities': {'volume': '13'}},
#  'set the volume to a level of 71': {'intent': 'volume.value',
#   'entities': {'volume': '71'}},
#  'set the volume to 23 using the speaker': {'intent': 'volume.value',
#   'entities': {'volume': '23'}},
#  ...}

# %%
list_entities, list_variables, list_num_variables = []

def entities():
    for i in content.values():
        for key, value in i['entities'].items():
            list_entities.append(f'{key} = {value}')
    
    return list_entities


def variables():
    variables = ['current_volume', 'volume_max', 'volume_increment', 'volume_decrement', 'last_volume']
    for i in list_entities:
        if j in variables:
            if j in i.split(' : ')[1]:
                
    
df = {
    "Utterance": [i for i in content.keys()],
    "Intent": [i['intent'] for i in content.values()],
    "Action": entities(),
    "Variables": variables(),
    "Num_Variables": None
}
# Out:
#   Cell In[62], line 13
#     if i.split(' : ')[1] in
#                             ^
# SyntaxError: invalid syntax

# %%
pd.DataFrame(df)
# Out:
#                                    Utterance           Intent  \
# 0                 reduce the volume adjuster  volume.decrease
# 1                bring down the sound output  volume.decrease
# 2                 decrease the volume output  volume.decrease
# 3         decrease the volume adjuster level  volume.decrease
# 4            make the volume setting quieter  volume.decrease
# ...                                      ...              ...
# 6368              turn the volume knob to 31     volume.value
# 6369   adjust the volume to 37 on the system     volume.value
# 6370               increase the volume to 82     volume.value
# 6371            adjust the sound level to 89     volume.value
# 6372  set the volume to 80 using the speaker     volume.value
#
#                                         Entities Variables
# 0     volume : current_volume - volume_decrement      None
# 1     volume : current_volume - volume_decrement      None
# 2     volume : current_volume - volume_decrement      None
# 3     volume : current_volume - volume_decrement      None
# 4     volume : current_volume - volume_decrement      None
# ...                                          ...       ...
# 6368                                 volume : 31      None
# 6369                                 volume : 37      None
# 6370                                 volume : 82      None
# 6371                                 volume : 89      None
# 6372                                 volume : 80      None
#
# [6373 rows x 4 columns]

# %%
import tensorflow as tf

tokenizer=tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(df['Utterance'])
df['Utterance']=tokenizer.texts_to_sequences(df['Utterance'])
# Out:
# 2023-01-28 17:35:52.125837: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
